# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Read all data.

main_puf = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_TRAUMA.csv", index_col = 'inc_key', low_memory = False)
preexisting_conditions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_PREEXISTINGCONDITIONS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
hospital_events = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_HOSPITALEVENTS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
ais = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_AISDIAGNOSIS_PIVOT.csv", index_col = 'inc_key', low_memory = False)
ecode = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_ECODE.csv", index_col = 'inc_key', low_memory = False)
interventions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_INTERVENTIONS.csv", index_col = 'Inc_Key', low_memory = False)
isolated_intraparenchymal_ids = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_intraparenchymal_ids.csv", index_col = 0, low_memory = False)
isolated_epidural_ids = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_epidural_ids.csv", index_col = 0, low_memory = False)
isolated_subdural_ids = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_subdural_ids.csv", index_col = 0, low_memory = False)
isolated_subarachnoid_ids = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_subarachnoid_ids.csv", index_col = 0, low_memory = False)

# %%
preexisting_conditions.head()
# Out:
#              CC_ADHD CC_ADLC CC_ALCOHOLISM CC_ANGINAPECTORIS CC_ANTICOAGULANT  \
# Inc_Key
# 210057637932      No      No            No                No               No
# 210057637933      No      No            No                No              Yes
# 210057637934      No      No            No                No              Yes
# 210057637935      No      No            No                No               No
# 210057637936      No      No            No                No               No
#
#              CC_BLEEDING CC_CHEMO CC_CHF CC_CIRRHOSIS CC_CONGENITAL  ...  \
# Inc_Key                                                              ...
# 210057637932          No       No     No           No            No  ...
# 210057637933          No       No     No           No            No  ...
# 210057637934          No       No     No           No            No  ...
# 210057637935          No       No     No           No            No  ...
# ...

# %%
data = pd.concat([main_puf, preexisting_conditions, hospital_events, ais, ecode, interventions], axis=1)

data.shape
# Out:
# (1209097, 301)

# %%
isolated_intraparenchymal_ids = list(isolated_intraparenchymal_ids.iloc[:,0])
isolated_epidural_ids = list(isolated_epidural_ids.iloc[:,0])
isolated_subdural_ids = list(isolated_subdural_ids.iloc[:,0])
isolated_subarachnoid_ids = list(isolated_subarachnoid_ids.iloc[:,0])

# %%
isolated_intraparenchymal = data.filter(items = isolated_intraparenchymal_ids, axis=0)

isolated_intraparenchymal.shape
# Out:
# (7807, 301)

# %%
isolated_epidural = data.filter(items = isolated_epidural_ids, axis=0)

isolated_epidural.shape
# Out:
# (4499, 301)

# %%
isolated_subdural = data.filter(items = isolated_subdural_ids, axis=0)

isolated_subdural.shape
# Out:
# (62380, 301)

# %%
isolated_subarachnoid = data.filter(items = isolated_subarachnoid_ids, axis=0)

isolated_subarachnoid.shape
# Out:
# (42904, 301)

# %%
#Save data frames.

isolated_intraparenchymal = pd.DataFrame(isolated_intraparenchymal)
isolated_intraparenchymal.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_intraparenchymal.csv')

isolated_epidural = pd.DataFrame(isolated_epidural)
isolated_epidural.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_epidural.csv')

isolated_subdural = pd.DataFrame(isolated_subdural)
isolated_subdural.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_subdural.csv')

isolated_subarachnoid = pd.DataFrame(isolated_subarachnoid)
isolated_subarachnoid.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_subarachnoid.csv')
