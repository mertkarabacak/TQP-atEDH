# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Read 2021 pre-existing conditions data.

data = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_HOSPITALEVENTS.csv", index_col = None, low_memory = False)

# %%
#Create columns for pivotting.

data.loc[(data['HOSPITALEVENT'] == 1) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_OTHER'] = 1
data.loc[(data['HOSPITALEVENT'] == 1) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_OTHER'] = 0
data.loc[(data['HOSPITALEVENT'] == 1) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_OTHER'] = 2
data.loc[(data['HOSPITALEVENT'] == 1) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_OTHER'] = 3

data.loc[(data['HOSPITALEVENT'] == 4) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_KIDNEY'] = 1
data.loc[(data['HOSPITALEVENT'] == 4) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_KIDNEY'] = 0
data.loc[(data['HOSPITALEVENT'] == 4) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_KIDNEY'] = 2
data.loc[(data['HOSPITALEVENT'] == 4) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_KIDNEY'] = 3

data.loc[(data['HOSPITALEVENT'] == 5) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_RESPIRATORY'] = 1
data.loc[(data['HOSPITALEVENT'] == 5) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_RESPIRATORY'] = 0
data.loc[(data['HOSPITALEVENT'] == 5) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_RESPIRATORY'] = 2
data.loc[(data['HOSPITALEVENT'] == 5) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_RESPIRATORY'] = 3

data.loc[(data['HOSPITALEVENT'] == 8) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_CARDARREST'] = 1
data.loc[(data['HOSPITALEVENT'] == 8) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_CARDARREST'] = 0
data.loc[(data['HOSPITALEVENT'] == 8) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_CARDARREST'] = 2
data.loc[(data['HOSPITALEVENT'] == 8) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_CARDARREST'] = 3

data.loc[((data['HOSPITALEVENT'] == 11) | (data['HOSPITALEVENT'] == 37)) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_PRESSUREULCER'] = 1
data.loc[(data['HC_PRESSUREULCER'] != 1), 'HC_PRESSUREULCER'] = 0
data.loc[((data['HOSPITALEVENT'] == 11) | (data['HOSPITALEVENT'] == 37)) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_PRESSUREULCER'] = 2
data.loc[((data['HOSPITALEVENT'] == 11) | (data['HOSPITALEVENT'] == 37)) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_PRESSUREULCER'] = 3

data.loc[(data['HOSPITALEVENT'] == 12) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_DEEPSSI'] = 1
data.loc[(data['HOSPITALEVENT'] == 12) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_DEEPSSI'] = 0
data.loc[(data['HOSPITALEVENT'] == 12) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_DEEPSSI'] = 2
data.loc[(data['HOSPITALEVENT'] == 12) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_DEEPSSI'] = 3

data.loc[(data['HOSPITALEVENT'] == 13) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_DRUGALCOHOLWITHDRAWAL'] = 1
data.loc[(data['HOSPITALEVENT'] == 13) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_DRUGALCOHOLWITHDRAWAL'] = 0
data.loc[(data['HOSPITALEVENT'] == 13) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_DRUGALCOHOLWITHDRAWAL'] = 2
data.loc[(data['HOSPITALEVENT'] == 13) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_DRUGALCOHOLWITHDRAWAL'] = 3

data.loc[(data['HOSPITALEVENT'] == 14) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_DVTHROMBOSIS'] = 1
data.loc[(data['HOSPITALEVENT'] == 14) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_DVTHROMBOSIS'] = 0
data.loc[(data['HOSPITALEVENT'] == 14) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_DVTHROMBOSIS'] = 2
data.loc[(data['HOSPITALEVENT'] == 14) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_DVTHROMBOSIS'] = 3

data.loc[(data['HOSPITALEVENT'] == 15) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_EXTREMITYCS'] = 1
data.loc[(data['HOSPITALEVENT'] == 15) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_EXTREMITYCS'] = 0
data.loc[(data['HOSPITALEVENT'] == 15) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_EXTREMITYCS'] = 2
data.loc[(data['HOSPITALEVENT'] == 15) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_EXTREMITYCS'] = 3

data.loc[(data['HOSPITALEVENT'] == 16) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_GRAFTFAIL'] = 1
data.loc[(data['HOSPITALEVENT'] == 16) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_GRAFTFAIL'] = 0
data.loc[(data['HOSPITALEVENT'] == 16) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_GRAFTFAIL'] = 2
data.loc[(data['HOSPITALEVENT'] == 16) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_GRAFTFAIL'] = 3

data.loc[(data['HOSPITALEVENT'] == 18) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_MI'] = 1
data.loc[(data['HOSPITALEVENT'] == 18) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_MI'] = 0
data.loc[(data['HOSPITALEVENT'] == 18) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_MI'] = 2
data.loc[(data['HOSPITALEVENT'] == 18) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_MI'] = 3

data.loc[(data['HOSPITALEVENT'] == 19) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_ORGANSPACESSI'] = 1
data.loc[(data['HOSPITALEVENT'] == 19) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_ORGANSPACESSI'] = 0
data.loc[(data['HOSPITALEVENT'] == 19) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_ORGANSPACESSI'] = 2
data.loc[(data['HOSPITALEVENT'] == 19) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_ORGANSPACESSI'] = 3

data.loc[(data['HOSPITALEVENT'] == 20) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_PNEUMONIA'] = 1
data.loc[(data['HOSPITALEVENT'] == 20) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_PNEUMONIA'] = 0
data.loc[(data['HOSPITALEVENT'] == 20) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_PNEUMONIA'] = 2
data.loc[(data['HOSPITALEVENT'] == 20) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_PNEUMONIA'] = 3

data.loc[(data['HOSPITALEVENT'] == 21) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_EMBOLISM'] = 1
data.loc[(data['HOSPITALEVENT'] == 21) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_EMBOLISM'] = 0
data.loc[(data['HOSPITALEVENT'] == 21) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_EMBOLISM'] = 2
data.loc[(data['HOSPITALEVENT'] == 21) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_EMBOLISM'] = 3

data.loc[(data['HOSPITALEVENT'] == 22) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_STROKECVA'] = 1
data.loc[(data['HOSPITALEVENT'] == 22) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_STROKECVA'] = 0
data.loc[(data['HOSPITALEVENT'] == 22) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_STROKECVA'] = 2
data.loc[(data['HOSPITALEVENT'] == 22) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_STROKECVA'] = 3

data.loc[((data['HOSPITALEVENT'] == 23) | (data['HOSPITALEVENT'] == 38)) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_SUPERFICIALSSI'] = 1
data.loc[(data['HC_SUPERFICIALSSI'] != 1), 'HC_SUPERFICIALSSI'] = 0
data.loc[((data['HOSPITALEVENT'] == 23) | (data['HOSPITALEVENT'] == 38)) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_SUPERFICIALSSI'] = 2
data.loc[((data['HOSPITALEVENT'] == 23) | (data['HOSPITALEVENT'] == 38)) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_SUPERFICIALSSI'] = 3

data.loc[(data['HOSPITALEVENT'] == 25) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_INTUBATION'] = 1
data.loc[(data['HOSPITALEVENT'] == 25) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_INTUBATION'] = 0
data.loc[(data['HOSPITALEVENT'] == 25) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_INTUBATION'] = 2
data.loc[(data['HOSPITALEVENT'] == 25) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_INTUBATION'] = 3

data.loc[(data['HOSPITALEVENT'] == 27) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_UTI'] = 1
data.loc[(data['HOSPITALEVENT'] == 27) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_UTI'] = 0
data.loc[(data['HOSPITALEVENT'] == 27) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_UTI'] = 2
data.loc[(data['HOSPITALEVENT'] == 27) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_UTI'] = 3

data.loc[(data['HOSPITALEVENT'] == 28) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_CRBSI'] = 1
data.loc[(data['HOSPITALEVENT'] == 28) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_CRBSI'] = 0
data.loc[(data['HOSPITALEVENT'] == 28) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_CRBSI'] = 2
data.loc[(data['HOSPITALEVENT'] == 28) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_CRBSI'] = 3

data.loc[(data['HOSPITALEVENT'] == 29) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_OSTEOMYELITIS'] = 1
data.loc[(data['HOSPITALEVENT'] == 29) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_OSTEOMYELITIS'] = 0
data.loc[(data['HOSPITALEVENT'] == 29) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_OSTEOMYELITIS'] = 2
data.loc[(data['HOSPITALEVENT'] == 29) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_OSTEOMYELITIS'] = 3

data.loc[(data['HOSPITALEVENT'] == 30) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_RETURNOR'] = 1
data.loc[(data['HOSPITALEVENT'] == 30) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_RETURNOR'] = 0
data.loc[(data['HOSPITALEVENT'] == 30) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_RETURNOR'] = 2
data.loc[(data['HOSPITALEVENT'] == 30) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_RETURNOR'] = 3

data.loc[(data['HOSPITALEVENT'] == 31) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_UNPLANNEDICU'] = 1
data.loc[(data['HOSPITALEVENT'] == 31) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_UNPLANNEDICU'] = 0
data.loc[(data['HOSPITALEVENT'] == 31) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_UNPLANNEDICU'] = 2
data.loc[(data['HOSPITALEVENT'] == 31) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_UNPLANNEDICU'] = 3

data.loc[(data['HOSPITALEVENT'] == 32) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_SEPSIS'] = 1
data.loc[(data['HOSPITALEVENT'] == 32) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_SEPSIS'] = 0
data.loc[(data['HOSPITALEVENT'] == 32) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_SEPSIS'] = 2
data.loc[(data['HOSPITALEVENT'] == 32) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_SEPSIS'] = 3

data.loc[(data['HOSPITALEVENT'] == 33) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_CAUTI'] = 1
data.loc[(data['HOSPITALEVENT'] == 33) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_CAUTI'] = 0
data.loc[(data['HOSPITALEVENT'] == 33) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_CAUTI'] = 2
data.loc[(data['HOSPITALEVENT'] == 33) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_CAUTI'] = 3

data.loc[(data['HOSPITALEVENT'] == 34) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_CLABSI'] = 1
data.loc[(data['HOSPITALEVENT'] == 34) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_CLABSI'] = 0
data.loc[(data['HOSPITALEVENT'] == 34) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_CLABSI'] = 2
data.loc[(data['HOSPITALEVENT'] == 34) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_CLABSI'] = 3

data.loc[(data['HOSPITALEVENT'] == 35) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_VAPNEUMONIA'] = 1
data.loc[(data['HOSPITALEVENT'] == 35) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_VAPNEUMONIA'] = 0
data.loc[(data['HOSPITALEVENT'] == 35) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_VAPNEUMONIA'] = 2
data.loc[(data['HOSPITALEVENT'] == 35) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_VAPNEUMONIA'] = 3

data.loc[(data['HOSPITALEVENT'] == 39) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_DELIRIUM'] = 1
data.loc[(data['HOSPITALEVENT'] == 39) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_DELIRIUM'] = 0
data.loc[(data['HOSPITALEVENT'] == 39) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_DELIRIUM'] = 2
data.loc[(data['HOSPITALEVENT'] == 39) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_DELIRIUM'] = 3

data.loc[(data['HOSPITALEVENT'] == 40) & (data['HOSPITALEVENTANSWER'] == 1), 'HC_RETURNOR'] = 1
data.loc[(data['HOSPITALEVENT'] == 40) & (data['HOSPITALEVENTANSWER'] == 2), 'HC_RETURNOR'] = 0
data.loc[(data['HOSPITALEVENT'] == 40) & (data['HOSPITALEVENTANSWER_BIU'] == 1), 'HC_RETURNOR'] = 2
data.loc[(data['HOSPITALEVENT'] == 40) & (data['HOSPITALEVENTANSWER_BIU'] == 2), 'HC_RETURNOR'] = 3

# %%
#Drop unwanted columns.

data.drop(['HOSPITALEVENT', 'HOSPITALEVENTANSWER', 'HOSPITALEVENTANSWER_BIU'], inplace=True,axis=1)

# %%
#Convert data frame to a pivot table.

pivot = pd.pivot_table(data=data, index=['Inc_Key'], aggfunc = np.sum)

# %%
#Replace label encoding with strings.

pivot = pivot.replace(0, 'No')
pivot = pivot.replace(1, 'Yes')
pivot = pivot.replace(2, 'Unknown')
pivot = pivot.replace(3, 'Unknown')

# %%
#Save pivot table for pre-existing conditions.

pivot.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_HOSPITALEVENTS_PIVOT.csv')
