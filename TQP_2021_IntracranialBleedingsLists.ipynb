# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Read ICD diagnoses data.

data = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_ICDDIAGNOSIS.csv", index_col = 'Inc_Key', low_memory = False)

# %%
intraparenchymal = list(data.loc[(data['ICDDIAGNOSISCODE'] == 'S06.340A') | (data['ICDDIAGNOSISCODE'] == 'S06.340D') | (data['ICDDIAGNOSISCODE'] == 'S06.340S') | (data['ICDDIAGNOSISCODE'] == 'S06.341A') | (data['ICDDIAGNOSISCODE'] == 'S06.341D') | (data['ICDDIAGNOSISCODE'] == 'S06.341S') | (data['ICDDIAGNOSISCODE'] == 'S06.342A')| (data['ICDDIAGNOSISCODE'] == 'S06.342D') | (data['ICDDIAGNOSISCODE'] == 'S06.342S') | (data['ICDDIAGNOSISCODE'] == 'S06.343A') | (data['ICDDIAGNOSISCODE'] == 'S06.343D') | (data['ICDDIAGNOSISCODE'] == 'S06.343S') | (data['ICDDIAGNOSISCODE'] == 'S06.344A') | (data['ICDDIAGNOSISCODE'] == 'S06.344D') | (data['ICDDIAGNOSISCODE'] == 'S06.344S') | (data['ICDDIAGNOSISCODE'] == 'S06.345A') | (data['ICDDIAGNOSISCODE'] == 'S06.345D') | (data['ICDDIAGNOSISCODE'] == 'S06.345S') | (data['ICDDIAGNOSISCODE'] == 'S06.346A') | (data['ICDDIAGNOSISCODE'] == 'S06.346D') | (data['ICDDIAGNOSISCODE'] == 'S06.346S') | (data['ICDDIAGNOSISCODE'] == 'S06.347A') | (data['ICDDIAGNOSISCODE'] == 'S06.347D') | (data['ICDDIAGNOSISCODE'] == 'S06.347S') | (data['ICDDIAGNOSISCODE'] == 'S06.348A') | (data['ICDDIAGNOSISCODE'] == 'S06.348S') | (data['ICDDIAGNOSISCODE'] == 'S06.349A') | (data['ICDDIAGNOSISCODE'] == 'S06.349D') | (data['ICDDIAGNOSISCODE'] == 'S06.349S') | (data['ICDDIAGNOSISCODE'] == 'S06.350A') | (data['ICDDIAGNOSISCODE'] == 'S06.350D') | (data['ICDDIAGNOSISCODE'] == 'S06.350S') | (data['ICDDIAGNOSISCODE'] == 'S06.351A') | (data['ICDDIAGNOSISCODE'] == 'S06.351D') | (data['ICDDIAGNOSISCODE'] == 'S06.351S') | (data['ICDDIAGNOSISCODE'] == 'S06.352A')| (data['ICDDIAGNOSISCODE'] == 'S06.352D') | (data['ICDDIAGNOSISCODE'] == 'S06.352S') | (data['ICDDIAGNOSISCODE'] == 'S06.353A') | (data['ICDDIAGNOSISCODE'] == 'S06.353D') | (data['ICDDIAGNOSISCODE'] == 'S06.353S') | (data['ICDDIAGNOSISCODE'] == 'S06.354A') | (data['ICDDIAGNOSISCODE'] == 'S06.354D') | (data['ICDDIAGNOSISCODE'] == 'S06.354S') | (data['ICDDIAGNOSISCODE'] == 'S06.355A') | (data['ICDDIAGNOSISCODE'] == 'S06.355D') | (data['ICDDIAGNOSISCODE'] == 'S06.355S') | (data['ICDDIAGNOSISCODE'] == 'S06.356A') | (data['ICDDIAGNOSISCODE'] == 'S06.356D') | (data['ICDDIAGNOSISCODE'] == 'S06.356S') | (data['ICDDIAGNOSISCODE'] == 'S06.357A') | (data['ICDDIAGNOSISCODE'] == 'S06.357D') | (data['ICDDIAGNOSISCODE'] == 'S06.357S') | (data['ICDDIAGNOSISCODE'] == 'S06.358A') | (data['ICDDIAGNOSISCODE'] == 'S06.358S') | (data['ICDDIAGNOSISCODE'] == 'S06.359A') | (data['ICDDIAGNOSISCODE'] == 'S06.359D') | (data['ICDDIAGNOSISCODE'] == 'S06.359S')].index.values)

epidural = list(data.loc[(data['ICDDIAGNOSISCODE'] == 'S06.4X0A') | (data['ICDDIAGNOSISCODE'] == 'S06.4X0D') | (data['ICDDIAGNOSISCODE'] == 'S06.4X0S') | (data['ICDDIAGNOSISCODE'] == 'S06.4X1A') | (data['ICDDIAGNOSISCODE'] == 'S06.4X1D') | (data['ICDDIAGNOSISCODE'] == 'S06.4X1S') | (data['ICDDIAGNOSISCODE'] == 'S06.4X2A')| (data['ICDDIAGNOSISCODE'] == 'S06.4X2D') | (data['ICDDIAGNOSISCODE'] == 'S06.4X2S') | (data['ICDDIAGNOSISCODE'] == 'S06.4X3A') | (data['ICDDIAGNOSISCODE'] == 'S06.4X3D') | (data['ICDDIAGNOSISCODE'] == 'S06.4X3S') | (data['ICDDIAGNOSISCODE'] == 'S06.4X4A') | (data['ICDDIAGNOSISCODE'] == 'S06.4X4D') | (data['ICDDIAGNOSISCODE'] == 'S06.4X4S') | (data['ICDDIAGNOSISCODE'] == 'S06.4X5A') | (data['ICDDIAGNOSISCODE'] == 'S06.4X5D') | (data['ICDDIAGNOSISCODE'] == 'S06.4X5S') | (data['ICDDIAGNOSISCODE'] == 'S06.4X6A') | (data['ICDDIAGNOSISCODE'] == 'S06.4X6D') | (data['ICDDIAGNOSISCODE'] == 'S06.4X6S') | (data['ICDDIAGNOSISCODE'] == 'S06.4X7A') | (data['ICDDIAGNOSISCODE'] == 'S06.4X7D') | (data['ICDDIAGNOSISCODE'] == 'S06.4X7S') | (data['ICDDIAGNOSISCODE'] == 'S06.4X8A') | (data['ICDDIAGNOSISCODE'] == 'S06.4X8S') | (data['ICDDIAGNOSISCODE'] == 'S06.4X9A') | (data['ICDDIAGNOSISCODE'] == 'S06.4X9D') | (data['ICDDIAGNOSISCODE'] == 'S06.4X9S')].index.values)

subdural = list(data.loc[(data['ICDDIAGNOSISCODE'] == 'S06.5X0A') | (data['ICDDIAGNOSISCODE'] == 'S06.5X0D') | (data['ICDDIAGNOSISCODE'] == 'S06.5X0S') | (data['ICDDIAGNOSISCODE'] == 'S06.5X1A') | (data['ICDDIAGNOSISCODE'] == 'S06.5X1D') | (data['ICDDIAGNOSISCODE'] == 'S06.5X1S') | (data['ICDDIAGNOSISCODE'] == 'S06.5X2A')| (data['ICDDIAGNOSISCODE'] == 'S06.5X2D') | (data['ICDDIAGNOSISCODE'] == 'S06.5X2S') | (data['ICDDIAGNOSISCODE'] == 'S06.5X3A') | (data['ICDDIAGNOSISCODE'] == 'S06.5X3D') | (data['ICDDIAGNOSISCODE'] == 'S06.5X3S') | (data['ICDDIAGNOSISCODE'] == 'S06.5X4A') | (data['ICDDIAGNOSISCODE'] == 'S06.5X4D') | (data['ICDDIAGNOSISCODE'] == 'S06.5X4S') | (data['ICDDIAGNOSISCODE'] == 'S06.5X5A') | (data['ICDDIAGNOSISCODE'] == 'S06.5X5D') | (data['ICDDIAGNOSISCODE'] == 'S06.5X5S') | (data['ICDDIAGNOSISCODE'] == 'S06.5X6A') | (data['ICDDIAGNOSISCODE'] == 'S06.5X6D') | (data['ICDDIAGNOSISCODE'] == 'S06.5X6S') | (data['ICDDIAGNOSISCODE'] == 'S06.5X7A') | (data['ICDDIAGNOSISCODE'] == 'S06.5X7D') | (data['ICDDIAGNOSISCODE'] == 'S06.5X7S') | (data['ICDDIAGNOSISCODE'] == 'S06.5X8A') | (data['ICDDIAGNOSISCODE'] == 'S06.5X8S') | (data['ICDDIAGNOSISCODE'] == 'S06.5X9A') | (data['ICDDIAGNOSISCODE'] == 'S06.5X9D') | (data['ICDDIAGNOSISCODE'] == 'S06.5X9S')].index.values)

subarachnoid = list(data.loc[(data['ICDDIAGNOSISCODE'] == 'S06.6X0A') | (data['ICDDIAGNOSISCODE'] == 'S06.6X0D') | (data['ICDDIAGNOSISCODE'] == 'S06.6X0S') | (data['ICDDIAGNOSISCODE'] == 'S06.6X1A') | (data['ICDDIAGNOSISCODE'] == 'S06.6X1D') | (data['ICDDIAGNOSISCODE'] == 'S06.6X1S') | (data['ICDDIAGNOSISCODE'] == 'S06.6X2A')| (data['ICDDIAGNOSISCODE'] == 'S06.6X2D') | (data['ICDDIAGNOSISCODE'] == 'S06.6X2S') | (data['ICDDIAGNOSISCODE'] == 'S06.6X3A') | (data['ICDDIAGNOSISCODE'] == 'S06.6X3D') | (data['ICDDIAGNOSISCODE'] == 'S06.6X3S') | (data['ICDDIAGNOSISCODE'] == 'S06.6X4A') | (data['ICDDIAGNOSISCODE'] == 'S06.6X4D') | (data['ICDDIAGNOSISCODE'] == 'S06.6X4S') | (data['ICDDIAGNOSISCODE'] == 'S06.6X5A') | (data['ICDDIAGNOSISCODE'] == 'S06.6X5D') | (data['ICDDIAGNOSISCODE'] == 'S06.6X5S') | (data['ICDDIAGNOSISCODE'] == 'S06.6X6A') | (data['ICDDIAGNOSISCODE'] == 'S06.6X6D') | (data['ICDDIAGNOSISCODE'] == 'S06.6X6S') | (data['ICDDIAGNOSISCODE'] == 'S06.6X7A') | (data['ICDDIAGNOSISCODE'] == 'S06.6X7D') | (data['ICDDIAGNOSISCODE'] == 'S06.6X7S') | (data['ICDDIAGNOSISCODE'] == 'S06.6X8A') | (data['ICDDIAGNOSISCODE'] == 'S06.6X8S') | (data['ICDDIAGNOSISCODE'] == 'S06.6X9A') | (data['ICDDIAGNOSISCODE'] == 'S06.6X9D') | (data['ICDDIAGNOSISCODE'] == 'S06.6X9S')].index.values)

# %%
print("Number of intraparenchymal bleeding patients before removing mixed bleedings: ", len(intraparenchymal))

isolated_intraparenchymal = set(intraparenchymal).difference(epidural)
isolated_intraparenchymal = set(isolated_intraparenchymal).difference(subdural)
isolated_intraparenchymal = set(isolated_intraparenchymal).difference(subarachnoid)

print("Number of isolated intraparenchymal bleeding patients after removing mixed bleedings: ", len(isolated_intraparenchymal))
# Out:
# Number of intraparenchymal bleeding patients before removing mixed bleedings:  30075
# Number of isolated intraparenchymal bleeding patients after removing mixed bleedings:  7807

# %%
print("Number of epidural bleeding patients before removing mixed bleedings: ", len(epidural))

isolated_epidural = set(epidural).difference(intraparenchymal)
isolated_epidural = set(isolated_epidural).difference(subdural)
isolated_epidural = set(isolated_epidural).difference(subarachnoid)

print("Number of isolated epidural bleeding patients after removing mixed bleedings: ", len(isolated_epidural))
# Out:
# Number of epidural bleeding patients before removing mixed bleedings:  11525
# Number of isolated epidural bleeding patients after removing mixed bleedings:  4499

# %%
print("Number of subdural bleeding patients before removing mixed bleedings: ", len(subdural))

isolated_subdural = set(subdural).difference(intraparenchymal)
isolated_subdural = set(isolated_subdural).difference(epidural)
isolated_subdural = set(isolated_subdural).difference(subarachnoid)

print("Number of isolated subdural bleeding patients after removing mixed bleedings: ", len(isolated_subdural))
# Out:
# Number of subdural bleeding patients before removing mixed bleedings:  123583
# Number of isolated subdural bleeding patients after removing mixed bleedings:  62380

# %%
print("Number of subarachnoid bleeding patients before removing mixed bleedings: ", len(subarachnoid))

isolated_subarachnoid = set(subarachnoid).difference(intraparenchymal)
isolated_subarachnoid = set(isolated_subarachnoid).difference(epidural)
isolated_subarachnoid = set(isolated_subarachnoid).difference(subdural)

print("Number of isolated subarachnoid bleeding patients after removing mixed bleedings: ", len(isolated_subarachnoid))
# Out:
# Number of subarachnoid bleeding patients before removing mixed bleedings:  102118
# Number of isolated subarachnoid bleeding patients after removing mixed bleedings:  42904

# %%
#Save patient lists as data frames.

isolated_intraparenchymal = pd.DataFrame(isolated_intraparenchymal)
isolated_intraparenchymal.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_intraparenchymal_ids.csv')

isolated_epidural = pd.DataFrame(isolated_epidural)
isolated_epidural.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_epidural_ids.csv')

isolated_subdural = pd.DataFrame(isolated_subdural)
isolated_subdural.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_subdural_ids.csv')

isolated_subarachnoid = pd.DataFrame(isolated_subarachnoid)
isolated_subarachnoid.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/isolated_subarachnoid_ids.csv')
