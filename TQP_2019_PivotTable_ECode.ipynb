# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Read lookup.

lookup = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_ECODE_LOOKUP.csv", index_col = None, low_memory = False)

# %%
INTENT = dict(zip(lookup.ECode, lookup.INTENT))
MECHANISM = dict(zip(lookup.ECode, lookup.MECHANISM))
TRAUMATYPE = dict(zip(lookup.ECode, lookup.TRAUMATYPE))

# %%
#Read data.

data = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_TRAUMA.csv", index_col = None, low_memory = False)

# %%
data = data[['inc_key', 'PRIMARYECODEICD10']]
data = data.set_index(['inc_key'])

# %%
data['INTENT'] = data['PRIMARYECODEICD10'].map(INTENT)
data['MECHANISM'] = data['PRIMARYECODEICD10'].map(MECHANISM)
data['TRAUMATYPE'] = data['PRIMARYECODEICD10'].map(TRAUMATYPE)

# %%
#Save data.

data.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_ECODE.csv')
