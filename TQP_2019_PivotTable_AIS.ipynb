# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Read AIS data.

data = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_AISDIAGNOSIS.csv", index_col = None, low_memory = False)

# %%
data['AISPreDot'] = data['AISPreDot'].apply(str)

# %%
if 'John' in list:
	print (" 'John' is found in the list")

# %%
def ais_region(ais_predot):
    if x in 
    return region

# %%
data['AISRegion'] = [ais_region(x) for x in data['ICD Code']]

# %%
data['AISRegion'].value_counts()
# Out:
# 8    804296
# 1    709229
# 7    595815
# 2    543727
# 4    466545
# 6    284128
# 5    202812
# 9     78046
# 3     36013
# n      2041
# Name: AISRegion, dtype: int64

# %%
agg_functions = {'AISVersion': 'first', 'AISSeverity': 'max'}

ais_1 = data.loc[(data['AISRegion'] == '1')]
ais_1 = ais_1.groupby(ais_1['inc_key']).aggregate(agg_functions)
ais_1.rename(columns={"AISSeverity": "AISSeverity1"}, inplace=True)
ais_1['AISSeverity2'] = 0
ais_1['AISSeverity3'] = 0
ais_1['AISSeverity4'] = 0
ais_1['AISSeverity5'] = 0
ais_1['AISSeverity6'] = 0
ais_1['AISSeverity7'] = 0
ais_1['AISSeverity8'] = 0
ais_1['AISSeverity9'] = 0

ais_2 = data.loc[(data['AISRegion'] == '2')]
ais_2 = ais_2.groupby(ais_2['inc_key']).aggregate(agg_functions)
ais_2.rename(columns={"AISSeverity": "AISSeverity2"}, inplace=True)
ais_2['AISSeverity1'] = 0
ais_2['AISSeverity3'] = 0
ais_2['AISSeverity4'] = 0
ais_2['AISSeverity5'] = 0
ais_2['AISSeverity6'] = 0
ais_2['AISSeverity7'] = 0
ais_2['AISSeverity8'] = 0
ais_2['AISSeverity9'] = 0

ais_3 = data.loc[(data['AISRegion'] == '3')]
ais_3 = ais_3.groupby(ais_3['inc_key']).aggregate(agg_functions)
ais_3.rename(columns={"AISSeverity": "AISSeverity3"}, inplace=True)
ais_3['AISSeverity1'] = 0
ais_3['AISSeverity2'] = 0
ais_3['AISSeverity4'] = 0
ais_3['AISSeverity5'] = 0
ais_3['AISSeverity6'] = 0
ais_3['AISSeverity7'] = 0
ais_3['AISSeverity8'] = 0
ais_3['AISSeverity9'] = 0

ais_4 = data.loc[(data['AISRegion'] == '4')]
ais_4 = ais_4.groupby(ais_4['inc_key']).aggregate(agg_functions)
ais_4.rename(columns={"AISSeverity": "AISSeverity4"}, inplace=True)
ais_4['AISSeverity1'] = 0
ais_4['AISSeverity2'] = 0
ais_4['AISSeverity3'] = 0
ais_4['AISSeverity5'] = 0
ais_4['AISSeverity6'] = 0
ais_4['AISSeverity7'] = 0
ais_4['AISSeverity8'] = 0
ais_4['AISSeverity9'] = 0

ais_5 = data.loc[(data['AISRegion'] == '5')]
ais_5 = ais_5.groupby(ais_5['inc_key']).aggregate(agg_functions)
ais_5.rename(columns={"AISSeverity": "AISSeverity5"}, inplace=True)
ais_5['AISSeverity1'] = 0
ais_5['AISSeverity2'] = 0
ais_5['AISSeverity3'] = 0
ais_5['AISSeverity4'] = 0
ais_5['AISSeverity6'] = 0
ais_5['AISSeverity7'] = 0
ais_5['AISSeverity8'] = 0
ais_5['AISSeverity9'] = 0

ais_6 = data.loc[(data['AISRegion'] == '6')]
ais_6 = ais_6.groupby(ais_6['inc_key']).aggregate(agg_functions)
ais_6.rename(columns={"AISSeverity": "AISSeverity6"}, inplace=True)
ais_6['AISSeverity1'] = 0
ais_6['AISSeverity2'] = 0
ais_6['AISSeverity3'] = 0
ais_6['AISSeverity4'] = 0
ais_6['AISSeverity5'] = 0
ais_6['AISSeverity7'] = 0
ais_6['AISSeverity8'] = 0
ais_6['AISSeverity9'] = 0

ais_7 = data.loc[(data['AISRegion'] == '7')]
ais_7 = ais_7.groupby(ais_7['inc_key']).aggregate(agg_functions)
ais_7.rename(columns={"AISSeverity": "AISSeverity7"}, inplace=True)
ais_7['AISSeverity1'] = 0
ais_7['AISSeverity2'] = 0
ais_7['AISSeverity3'] = 0
ais_7['AISSeverity4'] = 0
ais_7['AISSeverity5'] = 0
ais_7['AISSeverity6'] = 0
ais_7['AISSeverity8'] = 0
ais_7['AISSeverity9'] = 0

ais_8 = data.loc[(data['AISRegion'] == '8')]
ais_8 = ais_8.groupby(ais_8['inc_key']).aggregate(agg_functions)
ais_8.rename(columns={"AISSeverity": "AISSeverity8"}, inplace=True)
ais_8['AISSeverity1'] = 0
ais_8['AISSeverity2'] = 0
ais_8['AISSeverity3'] = 0
ais_8['AISSeverity4'] = 0
ais_8['AISSeverity5'] = 0
ais_8['AISSeverity6'] = 0
ais_8['AISSeverity7'] = 0
ais_8['AISSeverity9'] = 0

ais_9 = data.loc[(data['AISRegion'] == '9')]
ais_9 = ais_9.groupby(ais_9['inc_key']).aggregate(agg_functions)
ais_9.rename(columns={"AISSeverity": "AISSeverity9"}, inplace=True)
ais_9['AISSeverity1'] = 0
ais_9['AISSeverity2'] = 0
ais_9['AISSeverity3'] = 0
ais_9['AISSeverity4'] = 0
ais_9['AISSeverity5'] = 0
ais_9['AISSeverity6'] = 0
ais_9['AISSeverity7'] = 0
ais_9['AISSeverity8'] = 0

# %%
data = pd.concat([ais_1, ais_2, ais_3, ais_4, ais_5, ais_6, ais_7, ais_8, ais_9])
data['inc_key'] = data.index

# %%
agg_functions = {'AISVersion': 'first', 'AISSeverity1': 'max', 'AISSeverity2': 'max', 'AISSeverity3': 'max', 'AISSeverity4': 'max', 'AISSeverity5': 'max', 'AISSeverity6': 'max', 'AISSeverity7': 'max', 'AISSeverity8': 'max', 'AISSeverity9': 'max'}
data = data.groupby(data['inc_key']).aggregate(agg_functions)

# %%
#Save pivot table for AIS Scores.

data.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_AISDIAGNOSIS_PIVOT.csv')
