# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
#Read all data.

main_puf = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/PUF_TRAUMA.csv", index_col = 'inc_key', low_memory = False)
preexisting_conditions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/PUF_PREEXISTINGCONDITIONS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
hospital_events = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/PUF_HOSPITALEVENTS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
ais = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/PUF_AISDIAGNOSIS_PIVOT.csv", index_col = 'inc_key', low_memory = False)
ecode = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/PUF_ECODE.csv", index_col = 'inc_key', low_memory = False)
interventions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/PUF_INTERVENTIONS.csv", index_col = 'Inc_Key', low_memory = False)
isolated_intraparenchymal_ids = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/isolated_intraparenchymal_ids.csv", index_col = 0, low_memory = False)
isolated_epidural_ids = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/isolated_epidural_ids.csv", index_col = 0, low_memory = False)
isolated_subdural_ids = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/isolated_subdural_ids.csv", index_col = 0, low_memory = False)
isolated_subarachnoid_ids = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/isolated_subarachnoid_ids.csv", index_col = 0, low_memory = False)

# %%
data = pd.concat([main_puf, preexisting_conditions, hospital_events, ais, ecode, interventions], axis=1)

data.shape
# Out:
# (1135018, 352)

# %%
print(list(data.columns))
# Out:
# ['SEX', 'SEX_BIU', 'AGEyears', 'AMERICANINDIAN', 'ASIAN', 'BLACK', 'PACIFICISLANDER', 'RACEOTHER', 'WHITE', 'RACE_NA', 'RACE_UK', 'ETHNICITY', 'ETHNICITY_BIU', 'WORKRELATED', 'WORKRELATED_BIU', 'PTOCCUPATIONALINDUSTRY', 'PTOCCUPATIONALINDUSTRY_BIU', 'PATIENTSOCCUPATION', 'PATIENTSOCCUPATION_BIU', 'PLACEOFINJURYCODE', 'PLACEOFINJURYCODE_BIU', 'PRIMARYECODEICD10', 'PRIMARYECODEICD10_BIU', 'ADDITIONALECODE1', 'ADDITIONALECODE1_BIU', 'ADDITIONALECODE2', 'ADDITIONALECODE2_BIU', 'PROTDEV_NONE', 'PROTDEV_LAP_BELT', 'PROTDEV_PER_FLOAT', 'PROTDEV_PROTECT_GEAR', 'PROTDEV_EYE_PROTECT', 'PROTDEV_CHILD_RESTRAINT', 'PROTDEV_HELMET', 'PROTDEV_AIRBAG_PRESENT', 'PROTDEV_PROTECT_CLOTH', 'PROTDEV_SHOULDER_BELT', 'PROTDEV_OTHER', 'PROTDEV_NA', 'PROTDEV_UK', 'CHILDSPECIFICRESTRAINT', 'AIRBAG_NOTDEPLOYED', 'AIRBAG_DEPLOYED_FRNT', 'AIRBAG_DEPLOYED_SIDE', 'AIRBAG_DEPLOYED_OTHER', 'AIRBAG_DEPLOYED_NA', 'AIRBAG_DEPLOYED_UK', 'TRANSPORTMODE', 'TRANSPORTMODE_BIU', 'TM_GROUNDAMBULANCE', 'TM_HELICOPTERAMBULANCE',
# ...

# %%
data['INTERVENTION'].value_counts(normalize=False, dropna=False)
# Out:
# No     1105909
# Yes      29109
# Name: INTERVENTION, dtype: int64

# %%
isolated_intraparenchymal_ids = list(isolated_intraparenchymal_ids.iloc[:,0])
isolated_epidural_ids = list(isolated_epidural_ids.iloc[:,0])
isolated_subdural_ids = list(isolated_subdural_ids.iloc[:,0])
isolated_subarachnoid_ids = list(isolated_subarachnoid_ids.iloc[:,0])

# %%
isolated_intraparenchymal = data.filter(items = isolated_intraparenchymal_ids, axis=0)

isolated_intraparenchymal.shape
# Out:
# (7384, 352)

# %%
isolated_epidural = data.filter(items = isolated_epidural_ids, axis=0)

isolated_epidural.shape
# Out:
# (4444, 352)

# %%
isolated_subdural = data.filter(items = isolated_subdural_ids, axis=0)

isolated_subdural.shape
# Out:
# (56794, 352)

# %%
isolated_subarachnoid = data.filter(items = isolated_subarachnoid_ids, axis=0)

isolated_subarachnoid.shape
# Out:
# (39062, 352)

# %%
#Save data frames.

isolated_intraparenchymal = pd.DataFrame(isolated_intraparenchymal)
isolated_intraparenchymal.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/isolated_intraparenchymal.csv')

isolated_epidural = pd.DataFrame(isolated_epidural)
isolated_epidural.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/isolated_epidural.csv')

isolated_subdural = pd.DataFrame(isolated_subdural)
isolated_subdural.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/isolated_subdural.csv')

isolated_subarachnoid = pd.DataFrame(isolated_subarachnoid)
isolated_subarachnoid.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2020/isolated_subarachnoid.csv')
