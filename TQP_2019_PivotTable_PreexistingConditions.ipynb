# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Read 2021 pre-existing conditions data.

data = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_PREEXISTINGCONDITIONS.csv", index_col = None, low_memory = False)

# %%
#Create columns for pivotting.

data.loc[(data['PREEXISTINGCONDITION'] == 1) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_OTHER'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 1) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_OTHER'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 1) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_OTHER'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 1) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_OTHER'] = 3

data.loc[(data['PREEXISTINGCONDITION'] == 2) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_ALCOHOLISM'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 2) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_ALCOHOLISM'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 2) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_ALCOHOLISM'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 2) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_ALCOHOLISM'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 4) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_BLEEDING'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 4) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_BLEEDING'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 4) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_BLEEDING'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 4) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_BLEEDING'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 5) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_CHEMO'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 5) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_CHEMO'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 5) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_CHEMO'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 5) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_CHEMO'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 6) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_CONGENITAL'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 6) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_CONGENITAL'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 6) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_CONGENITAL'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 6) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_CONGENITAL'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 7) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_CHF'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 7) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_CHF'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 7) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_CHF'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 7) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_CHF'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 8) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_SMOKING'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 8) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_SMOKING'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 8) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_SMOKING'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 8) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_SMOKING'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 9) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_RENAL'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 9) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_RENAL'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 9) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_RENAL'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 9) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_RENAL'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 10) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_CVA'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 10) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_CVA'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 10) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_CVA'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 10) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_CVA'] = 3
                                                            
data.loc[(data['PREEXISTINGCONDITION'] == 11) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_DIABETES'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 11) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_DIABETES'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 11) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_DIABETES'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 11) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_DIABETES'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 12) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_DISCANCER'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 12) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_DISCANCER'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 12) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_DISCANCER'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 12) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_DISCANCER'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 13) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_ADLC'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 13) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_ADLC'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 13) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_ADLC'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 13) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_ADLC'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 15) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_FUNCTIONAL'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 15) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_FUNCTIONAL'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 15) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_FUNCTIONAL'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 15) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_FUNCTIONAL'] = 3
                                                           
data.loc[((data['PREEXISTINGCONDITION'] == 16) | (data['PREEXISTINGCONDITION'] == 32)) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_ANGINAPECTORIS'] = 1
data.loc[(data['CC_ANGINAPECTORIS'] != 1), 'CC_ANGINAPECTORIS'] = 0
data.loc[((data['PREEXISTINGCONDITION'] == 16) | (data['PREEXISTINGCONDITION'] == 32)) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_ANGINAPECTORIS'] = 2
data.loc[((data['PREEXISTINGCONDITION'] == 16) | (data['PREEXISTINGCONDITION'] == 32)) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_ANGINAPECTORIS'] = 3

data.loc[((data['PREEXISTINGCONDITION'] == 17) | (data['PREEXISTINGCONDITION'] == 34)) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_MI'] = 1
data.loc[(data['CC_MI'] != 1), 'CC_MI'] = 0
data.loc[((data['PREEXISTINGCONDITION'] == 17) | (data['PREEXISTINGCONDITION'] == 34)) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_MI'] = 2
data.loc[((data['PREEXISTINGCONDITION'] == 17) | (data['PREEXISTINGCONDITION'] == 34)) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_MI'] = 3

data.loc[((data['PREEXISTINGCONDITION'] == 18) | (data['PREEXISTINGCONDITION'] == 35)) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_PAD'] = 1
data.loc[(data['CC_PAD'] != 1), 'CC_PAD'] = 0
data.loc[((data['PREEXISTINGCONDITION'] == 18) | (data['PREEXISTINGCONDITION'] == 35)) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_PAD'] = 2
data.loc[((data['PREEXISTINGCONDITION'] == 18) | (data['PREEXISTINGCONDITION'] == 35)) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_PAD'] = 3

data.loc[(data['PREEXISTINGCONDITION'] == 19) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_HYPERTENSION'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 19) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_HYPERTENSION'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 19) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_HYPERTENSION'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 19) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_HYPERTENSION'] = 3
                                                           
data.loc[((data['PREEXISTINGCONDITION'] == 21) | (data['PREEXISTINGCONDITION'] == 37)) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_PREMATURITY'] = 1
data.loc[(data['CC_PREMATURITY'] != 1), 'CC_PREMATURITY'] = 0
data.loc[((data['PREEXISTINGCONDITION'] == 21) | (data['PREEXISTINGCONDITION'] == 37)) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_PREMATURITY'] = 2
data.loc[((data['PREEXISTINGCONDITION'] == 21) | (data['PREEXISTINGCONDITION'] == 37)) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_PREMATURITY'] = 3

data.loc[(data['PREEXISTINGCONDITION'] == 23) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_COPD'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 23) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_COPD'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 23) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_COPD'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 23) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_COPD'] = 3
 
data.loc[(data['PREEXISTINGCONDITION'] == 24) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_STEROID'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 24) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_STEROID'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 24) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_STEROID'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 24) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_STEROID'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 25) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_CIRRHOSIS'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 25) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_CIRRHOSIS'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 25) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_CIRRHOSIS'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 25) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_CIRRHOSIS'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 26) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_DEMENTIA'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 26) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_DEMENTIA'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 26) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_DEMENTIA'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 26) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_DEMENTIA'] = 3
                                                           
data.loc[((data['PREEXISTINGCONDITION'] == 28) | (data['PREEXISTINGCONDITION'] == 36)) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_SUBSTANCEABUSE'] = 1
data.loc[(data['CC_SUBSTANCEABUSE'] != 1), 'CC_SUBSTANCEABUSE'] = 0
data.loc[((data['PREEXISTINGCONDITION'] == 28) | (data['PREEXISTINGCONDITION'] == 36)) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_SUBSTANCEABUSE'] = 2
data.loc[((data['PREEXISTINGCONDITION'] == 28) | (data['PREEXISTINGCONDITION'] == 36)) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_SUBSTANCEABUSE'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 30) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_ADHD'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 30) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_ADHD'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 30) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_ADHD'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 30) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_ADHD'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 31) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_ANTICOAGULANT'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 31) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_ANTICOAGULANT'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 31) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_ANTICOAGULANT'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 31) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_ANTICOAGULANT'] = 3
                                                           
data.loc[(data['PREEXISTINGCONDITION'] == 33) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_MENTALPERSONALITY'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 33) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_MENTALPERSONALITY'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 33) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_MENTALPERSONALITY'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 33) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_MENTALPERSONALITY'] = 3

data.loc[(data['PREEXISTINGCONDITION'] == 38) & (data['PREEXISTINGCONDITIONANSWER'] == 1), 'CC_PREGNANCY'] = 1
data.loc[(data['PREEXISTINGCONDITION'] == 38) & (data['PREEXISTINGCONDITIONANSWER'] == 2), 'CC_PREGNANCY'] = 0
data.loc[(data['PREEXISTINGCONDITION'] == 38) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 1), 'CC_PREGNANCY'] = 2
data.loc[(data['PREEXISTINGCONDITION'] == 38) & (data['PREEXISTINGCONDITIONANSWER_BIU'] == 2), 'CC_PREGNANCY'] = 3

# %%
#Drop unwanted columns.

data.drop(['PREEXISTINGCONDITION', 'PREEXISTINGCONDITIONANSWER', 'PREEXISTINGCONDITIONANSWER_BIU'],inplace=True,axis=1)

# %%
#Convert data frame to a pivot table.

pivot = pd.pivot_table(data=data, index=['Inc_Key'], aggfunc = np.sum)

# %%
#Replace label encoding with strings.

pivot = pivot.replace(0, 'No')
pivot = pivot.replace(1, 'Yes')
pivot = pivot.replace(2, 'Unknown')
pivot = pivot.replace(3, 'Unknown')

# %%
#Save pivot table for pre-existing conditions.

pivot.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_PREEXISTINGCONDITIONS_PIVOT.csv')

# %%
pivot.columns
# Out:
# Index(['CC_ADHD', 'CC_ADLC', 'CC_ALCOHOLISM', 'CC_ANGINAPECTORIS',
#        'CC_ANTICOAGULANT', 'CC_BLEEDING', 'CC_CHEMO', 'CC_CHF', 'CC_CIRRHOSIS',
#        'CC_CONGENITAL', 'CC_COPD', 'CC_CVA', 'CC_DEMENTIA', 'CC_DIABETES',
#        'CC_DISCANCER', 'CC_FUNCTIONAL', 'CC_HYPERTENSION',
#        'CC_MENTALPERSONALITY', 'CC_MI', 'CC_OTHER', 'CC_PAD', 'CC_PREGNANCY',
#        'CC_PREMATURITY', 'CC_RENAL', 'CC_SMOKING', 'CC_STEROID',
#        'CC_SUBSTANCEABUSE'],
#       dtype='object')
