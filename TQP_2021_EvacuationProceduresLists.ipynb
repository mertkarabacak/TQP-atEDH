# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Read ICD diagnoses data.

data = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_ICDPROCEDURE.csv", index_col = 'Inc_Key', low_memory = False)

# %%
intraparenchymal = list(data.loc[(data['ICDPROCEDURECODE'] == '009700Z') | (data['ICDPROCEDURECODE'] == '00970ZX') | (data['ICDPROCEDURECODE'] == '00970ZX') | (data['ICDPROCEDURECODE'] == '009730Z') | (data['ICDPROCEDURECODE'] == '00973ZX') | (data['ICDPROCEDURECODE'] == '00973ZZ') | (data['ICDPROCEDURECODE'] == '009740Z') | (data['ICDPROCEDURECODE'] == '00974ZX') | (data['ICDPROCEDURECODE'] == '00974ZZ') ].index.values)

epidural = list(data.loc[(data['ICDPROCEDURECODE'] == '009300Z') | (data['ICDPROCEDURECODE'] == '00930ZX') | (data['ICDPROCEDURECODE'] == '00930ZX') | (data['ICDPROCEDURECODE'] == '009330Z') | (data['ICDPROCEDURECODE'] == '00933ZX') | (data['ICDPROCEDURECODE'] == '00933ZZ') | (data['ICDPROCEDURECODE'] == '009340Z') | (data['ICDPROCEDURECODE'] == '00934ZX') | (data['ICDPROCEDURECODE'] == '00934ZZ') ].index.values)

subdural = list(data.loc[(data['ICDPROCEDURECODE'] == '009400Z') | (data['ICDPROCEDURECODE'] == '00940ZX') | (data['ICDPROCEDURECODE'] == '00940ZX') | (data['ICDPROCEDURECODE'] == '009430Z') | (data['ICDPROCEDURECODE'] == '00943ZX') | (data['ICDPROCEDURECODE'] == '00943ZZ') | (data['ICDPROCEDURECODE'] == '009440Z') | (data['ICDPROCEDURECODE'] == '00944ZX') | (data['ICDPROCEDURECODE'] == '00944ZZ') ].index.values)

subarachnoid = list(data.loc[(data['ICDPROCEDURECODE'] == '009500Z') | (data['ICDPROCEDURECODE'] == '00950ZX') | (data['ICDPROCEDURECODE'] == '00950ZX') | (data['ICDPROCEDURECODE'] == '009530Z') | (data['ICDPROCEDURECODE'] == '00953ZX') | (data['ICDPROCEDURECODE'] == '00953ZZ') | (data['ICDPROCEDURECODE'] == '009540Z') | (data['ICDPROCEDURECODE'] == '00954ZX') | (data['ICDPROCEDURECODE'] == '00954ZZ') ].index.values)

# %%
#Save patient lists as data frames.

intraparenchymal = pd.DataFrame(intraparenchymal)
intraparenchymal.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/intraparenchymal_evac_ids.csv')

epidural = pd.DataFrame(epidural)
epidural.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/epidural_evac_ids.csv')

subdural = pd.DataFrame(subdural)
subdural.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/subdural_evac_ids.csv')

subarachnoid = pd.DataFrame(subarachnoid)
subarachnoid.to_csv('/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/subarachnoid_evac_ids.csv')
